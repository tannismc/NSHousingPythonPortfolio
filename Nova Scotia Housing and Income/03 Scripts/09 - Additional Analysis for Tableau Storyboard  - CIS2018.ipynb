# %% [markdown]
# # Tannis McCartney
# ## June 27, 2022
# ## Additional analysis/visuals for Tableau

# %% [markdown]
# #### Table of Contents
# 01 Import Libraries
#
# 02 Import Dataset
#
# 03 Population of Canada by Province
#
# 04 Affordable Housing by Province
#
# 05 After-tax income brackets
#
# 06 Age group
#
# 07 Household size
#
# 08 Low income flags
#
# 09 Disposable income flag
#
# 10 Ownership of dwelling
#
# 11 Affordable housing
#
# 12 Total household costs flag

# %% [markdown]
# # 01 Import libraries

# %%
# Import libraries for analysis
import pandas as pd
import numpy as np
import os

# %%
# Import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # 02 Import data

# %%
# Turn project folder path into a string
path = r'C:\Users\tmmcc\Google Drive\Data Analytics Bootcamp\6 Advanced Analytics and Dashboard Design\Nova Scotia Housing and Income'

# %%
# Load 2018 Canadian Income Survey
CIS2018 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'CIS2018_subset.pkl'))
CIS2018.head()
# Out:
#    household_id  person_id  sample_weight          province       age_group  \
# 0          2129     212901       208.9708           Ontario  25 to 29 years
# 1          2129     212902       208.9708           Ontario  25 to 29 years
# 2          2130     213001      1101.2217  British Columbia  45 to 49 years
# 3          2130     213002      1101.2217  British Columbia  55 to 59 years
# 4          2131     213101       165.3016      Saskatchewan  55 to 59 years
#
#    gender marital_status  after_tax_income  household_size  \
# 0  Female     Common-law           44265.0               2
# 1    Male     Common-law           42985.0               2
# 2  Female     Common-law           82370.0               2
# 3  Female     Common-law           49105.0               2
# 4  Female        Married           21000.0               2
#
#                               household_composition  ...  \
# 0  Two or more person household/One economic family  ...
# 1  Two or more person household/One economic family  ...
# 2  Two or more person household/One economic family  ...
# 3  Two or more person household/One economic family  ...
# 4  Two or more person household/One economic family  ...
#
#   disposable_income_below_mbm_flag                   ownership_of_dwelling  \
# 0                               No      Owned by a member of the household
# 1                               No      Owned by a member of the household
# 2                               No  Not owned by a member of the household
# 3                               No  Not owned by a member of the household
# 4                               No      Owned by a member of the household
#
#   monthly_mortgage_payment monthly_condo_fee monthly_rent rent_subsidy_flag  \
# 0                   2000.0               NaN          NaN        Valid skip
# 1                   2000.0               NaN          NaN        Valid skip
# 2                      NaN               NaN       2900.0                No
# 3                      NaN               NaN       2900.0                No
# 4                   1600.0               NaN          NaN        Valid skip
#
#    core_housing_need_indicator  adult_food_security_status  \
# 0     Not in core housing need                 Food secure
# 1     Not in core housing need                 Food secure
# 2     Not in core housing need                 Food secure
# 3     Not in core housing need                 Food secure
# 4     Not in core housing need                 Food secure
#
#    child_food_security_status household_food_security_status
# 0                  Valid skip                    Food secure
# 1                  Valid skip                    Food secure
# 2                  Valid skip                    Food secure
# 3                  Valid skip                    Food secure
# 4                  Valid skip                    Food secure
#
# [5 rows x 24 columns]

# %%
# Check sum of sample_weight column: it should approximate the population of Canada
CIS2018['sample_weight'].sum()
# Out:
# 36329666.0139

# %% [markdown]
# # 03 Population of Canada by Province

# %%
# Apply weight to population numbers and convert series to dataframe
pop = CIS2018.groupby('province')['sample_weight'].sum()
pop = pop.to_frame()

# %%
# Rename columns
pop = pop.rename(columns={'sample_weight':'population'})

# %%
# View data
round(pop)
# Out:
#                            population
# province
# Alberta                     4295760.0
# British Columbia            4747510.0
# Manitoba                    1260815.0
# New Brunswick                737522.0
# Newfoundland and Labrador    514230.0
# Nova Scotia                  934556.0
# Ontario                    14262158.0
# Prince Edward Island         151906.0
# Quebec                      8333951.0
# Saskatchewan                1091258.0

# %%
# Export weighted table 
pop.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Canada_population.csv'))

# %% [markdown]
# # 04 Affordable Housing

# %%
df = CIS2018.loc[CIS2018['household_maj_income_flag']=='Yes']
df.shape
# Out:
# (40857, 24)

# %%
# Calculate 35% of after-tax income and divide by twelve
df['atinc35'] = df['after_tax_income'].apply(lambda x: x*.02917)
# Out:
# C:\Users\tmmcc\AppData\Local\Temp\ipykernel_9908\3247374079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['atinc35'] = df['after_tax_income'].apply(lambda x: x*.02917)

# %%
# Calculate total housing costs (mortgage, mortgage + condo fees, or rent)
df['total_household_costs'] = df[['monthly_mortgage_payment', 'monthly_condo_fee', 'monthly_rent']].sum(axis=1)
# Out:
# C:\Users\tmmcc\AppData\Local\Temp\ipykernel_9908\1242605668.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_household_costs'] = df[['monthly_mortgage_payment', 'monthly_condo_fee', 'monthly_rent']].sum(axis=1)

# %%
# Check data
df.head(50)
# Out:
#      household_id  person_id  sample_weight                   province  \
# 0            2129     212901       208.9708                    Ontario
# 2            2130     213001      1101.2217           British Columbia
# 5            2131     213102       165.3016               Saskatchewan
# 6            2132     213201       126.5388                   Manitoba
# 11           2133     213302       119.6088                Nova Scotia
# 14           2134     213402       152.1021                Nova Scotia
# 16           2135     213501       967.0087                    Ontario
# 18           2136     213601        55.8415              New Brunswick
# 24           2137     213702      1329.0825                    Ontario
# 26           2138     213802       340.4773                    Ontario
# 28           2139     213901       405.9476                    Ontario
# 32           2140     214001        42.8058       Prince Edward Island
# 36           2141     214101        96.3575                    Ontario
# 38           2142     214201       234.0773               Saskatchewan
# 40           2143     214302       980.9425                     Quebec
# 41           2144     214401       143.8502                    Alberta
# 44           2145     214502       134.4715                Nova Scotia
# 46           2146     214602       129.9580           British Columbia
# 48           2147     214701       142.0839                     Quebec
# 51           2148     214803       140.2521                     Quebec
# 52           2149     214901       143.0196              New Brunswick
# 54           2150     215002       106.6849                     Quebec
# 58           2151     215103       293.9710                    Alberta
# 59           2152     215201       128.2818                     Quebec
# 61           2153     215302       333.4542                    Ontario
# 64           2154     215401        95.9375                     Quebec
# 69           2155     215501       321.3549                   Manitoba
# 71           2156     215602       484.3815                   Manitoba
# 77           2157     215701       621.5840                     Quebec
# 78           2158     215801       164.9741                     Quebec
# 79           2159     215902       119.8485                     Quebec
# 80           2160     216001       133.5902  Newfoundland and Labrador
# 82           2161     216101       100.2271                    Alberta
# 84           2162     216202      2557.6225                    Ontario
# 86           2163     216301        67.9710                    Ontario
# 87           2164     216401        89.1311                    Alberta
# 89           2165     216501        27.0400               Saskatchewan
# 91           2166     216601       224.1435           British Columbia
# 96           2167     216701       701.2165                     Quebec
# 102          2168     216801       201.9227                    Ontario
# 105          2169     216902        32.8940                    Alberta
# 106          2170     217001       155.9273                    Alberta
# 108          2171     217101       327.8095           British Columbia
# 110          2172     217201       442.9536                     Quebec
# 113          2173     217302       134.5102                     Quebec
# 115          2174     217402       478.1335                     Quebec
# 118          2175     217502       515.1333                     Quebec
# 120          2176     217601       436.7897                    Ontario
# 121          2177     217701       151.7840                    Alberta
# 124          2178     217801       402.9590                    Ontario
#
#              age_group  gender                  marital_status  \
# 0       25 to 29 years  Female                      Common-law
# 2       45 to 49 years  Female                      Common-law
# 5       55 to 59 years    Male                         Married
# 6       35 to 39 years    Male                         Married
# 11      35 to 39 years  Female                         Married
# 14      25 to 29 years    Male                      Not stated
# 16      65 to 69 years  Female                      Not stated
# 18      30 to 34 years  Female          Single (never married)
# 24      30 to 34 years  Female                         Married
# 26      40 to 44 years  Female                         Married
# 28      45 to 49 years    Male                         Married
# 32      45 to 49 years  Female                         Married
# 36   70 years and over  Female  Separated, divorced or widowed
# 38      50 to 54 years  Female          Single (never married)
# 40      18 to 24 years    Male          Single (never married)
# 41      25 to 29 years  Female                         Married
# 44      55 to 59 years    Male                         Married
# 46      35 to 39 years  Female  Separated, divorced or widowed
# 48      30 to 34 years    Male          Single (never married)
# 51      25 to 29 years    Male          Single (never married)
# 52   70 years and over  Female  Separated, divorced or widowed
# 54      40 to 44 years  Female                      Common-law
# 58      25 to 29 years  Female          Single (never married)
# 59      50 to 54 years  Female          Single (never married)
# 61      40 to 44 years    Male                         Married
# 64      40 to 44 years  Female                         Married
# 69      30 to 34 years  Female          Single (never married)
# 71      40 to 44 years  Female                      Not stated
# 77   70 years and over  Female  Separated, divorced or widowed
# 78      65 to 69 years  Female  Separated, divorced or widowed
# 79   70 years and over    Male          Single (never married)
# 80      50 to 54 years  Female          Single (never married)
# 82      30 to 34 years    Male          Single (never married)
# 84      50 to 54 years  Female          Single (never married)
# 86      30 to 34 years  Female          Single (never married)
# 87   70 years and over  Female                         Married
# 89      18 to 24 years    Male                      Not stated
# 91      30 to 34 years    Male                         Married
# 96      50 to 54 years  Female                      Not stated
# 102     65 to 69 years    Male                         Married
# 105     18 to 24 years  Female                      Not stated
# 106     50 to 54 years    Male                      Common-law
# 108  70 years and over  Female          Single (never married)
# 110     65 to 69 years  Female                         Married
# 113     55 to 59 years    Male                      Common-law
# 115     40 to 44 years  Female                      Common-law
# 118     45 to 49 years  Female          Single (never married)
# 120     45 to 49 years  Female          Single (never married)
# 121     45 to 49 years  Female                         Married
# 124     50 to 54 years  Female                         Married
#
#      after_tax_income  household_size  \
# 0             44265.0               2
# 2             82370.0               2
# 5            112195.0               2
# 6             70725.0               4
# 11            32160.0               3
# 14            33325.0               3
# 16            59095.0               2
# 18            64560.0               5
# 24            65155.0               2
# 26            69590.0               3
# 28            66570.0               4
# 32            55025.0               4
# 36            36145.0               2
# 38            13575.0               1
# 40            28285.0               2
# 41             6925.0               2
# 44            65360.0               2
# 46            58495.0               3
# 48            40410.0               1
# 51            43950.0               3
# 52            30075.0               1
# 54            79130.0               4
# 58            20575.0               2
# 59            84580.0               1
# 61            38815.0               4
# 64            57530.0               5
# 69            22235.0               1
# 71            33975.0               7
# 77            22070.0               1
# 78            23775.0               1
# 79            20575.0               1
# 80            66660.0               2
# 82            57680.0               1
# 84            14100.0               3
# 86            75780.0               1
# 87            23700.0               2
# 89            61240.0               2
# 91           100700.0               5
# 96            42660.0               6
# 102           51845.0               2
# 105           51400.0               2
# 106          102590.0               2
# 108           53275.0               2
# 110           21825.0               2
# 113           46000.0               2
# 115           52200.0               3
# 118           33275.0               3
# 120           18055.0               1
# 121           69625.0               3
# 124           81635.0               4
#
#                                  household_composition  ...  \
# 0     Two or more person household/One economic family  ...
# 2     Two or more person household/One economic family  ...
# 5     Two or more person household/One economic family  ...
# 6     Two or more person household/One economic family  ...
# 11    Two or more person household/One economic family  ...
# 14    Two or more person household/One economic family  ...
# 16    Two or more person household/One economic family  ...
# 18    Two or more person household/One economic family  ...
# 24    Two or more person household/One economic family  ...
# 26    Two or more person household/One economic family  ...
# 28    Two or more person household/One economic family  ...
# 32    Two or more person household/One economic family  ...
# 36    Two or more person household/One economic family  ...
# 38                                One person household  ...
# 40   Two or more person household/Two or more econo...  ...
# 41    Two or more person household/One economic family  ...
# 44    Two or more person household/One economic family  ...
# 46    Two or more person household/One economic family  ...
# 48                                One person household  ...
# 51    Two or more person household/One economic family  ...
# 52                                One person household  ...
# 54    Two or more person household/One economic family  ...
# 58    Two or more person household/One economic family  ...
# 59                                One person household  ...
# 61    Two or more person household/One economic family  ...
# 64    Two or more person household/One economic family  ...
# 69                                One person household  ...
# 71    Two or more person household/One economic family  ...
# 77                                One person household  ...
# 78                                One person household  ...
# 79                                One person household  ...
# 80    Two or more person household/One economic family  ...
# 82                                One person household  ...
# 84   Two or more person household/Two or more econo...  ...
# 86                                One person household  ...
# 87    Two or more person household/One economic family  ...
# 89    Two or more person household/One economic family  ...
# 91    Two or more person household/One economic family  ...
# 96    Two or more person household/One economic family  ...
# 102   Two or more person household/One economic family  ...
# 105   Two or more person household/One economic family  ...
# 106   Two or more person household/One economic family  ...
# 108   Two or more person household/One economic family  ...
# 110   Two or more person household/One economic family  ...
# 113   Two or more person household/One economic family  ...
# 115   Two or more person household/One economic family  ...
# 118   Two or more person household/One economic family  ...
# 120                               One person household  ...
# 121   Two or more person household/One economic family  ...
# 124   Two or more person household/One economic family  ...
#
#     monthly_mortgage_payment monthly_condo_fee monthly_rent rent_subsidy_flag  \
# 0                     2000.0               NaN          NaN        Valid skip
# 2                        NaN               NaN       2900.0                No
# 5                     1600.0               NaN          NaN        Valid skip
# 6                     1700.0               NaN          NaN        Valid skip
# 11                     400.0               NaN          NaN        Valid skip
# 14                    1100.0               NaN          NaN        Valid skip
# 16                       NaN               NaN          NaN        Valid skip
# 18                       NaN               NaN        500.0        Not stated
# 24                    2100.0               NaN          NaN        Valid skip
# 26                    3300.0               NaN          NaN        Valid skip
# 28                    1100.0               NaN          NaN        Valid skip
# 32                     800.0               NaN          NaN        Valid skip
# 36                       NaN               NaN          NaN        Valid skip
# 38                       NaN               NaN        500.0        Not stated
# 40                       NaN               NaN        600.0                No
# 41                       NaN               NaN        900.0                No
# 44                    1200.0               NaN          NaN        Valid skip
# 46                       NaN               NaN          NaN        Valid skip
# 48                    1500.0               NaN          NaN        Valid skip
# 51                     500.0               NaN          NaN        Valid skip
# 52                       NaN               NaN          NaN        Valid skip
# 54                     800.0               NaN          NaN        Valid skip
# 58                       NaN               NaN       1000.0                No
# 59                       NaN               NaN          NaN        Valid skip
# 61                       NaN               NaN       1400.0                No
# 64                     900.0               NaN          NaN        Valid skip
# 69                    2300.0               NaN          NaN        Valid skip
# 71                       NaN               NaN        600.0        Not stated
# 77                       NaN               NaN          NaN        Valid skip
# 78                       NaN               NaN        500.0                No
# 79                       NaN               NaN        500.0               Yes
# 80                       NaN               NaN          NaN        Valid skip
# 82                    1500.0               NaN          NaN        Valid skip
# 84                       NaN               NaN        900.0                No
# 86                       NaN               NaN       1200.0                No
# 87                       NaN               NaN          NaN        Valid skip
# 89                     800.0               NaN          NaN        Valid skip
# 91                    2000.0               NaN          NaN        Valid skip
# 96                    1100.0               NaN          NaN        Valid skip
# 102                      NaN               NaN          NaN        Valid skip
# 105                      NaN               NaN       1800.0        Not stated
# 106                      NaN               NaN        900.0                No
# 108                      NaN               NaN          NaN        Valid skip
# 110                      NaN               NaN          NaN        Valid skip
# 113                    700.0               NaN          NaN        Valid skip
# 115                    500.0               NaN          NaN        Valid skip
# 118                      NaN               NaN        600.0        Not stated
# 120                      NaN               NaN        200.0                No
# 121                   1100.0               NaN          NaN        Valid skip
# 124                   1800.0               NaN          NaN        Valid skip
#
#     core_housing_need_indicator adult_food_security_status  \
# 0      Not in core housing need                Food secure
# 2      Not in core housing need                Food secure
# 5      Not in core housing need                Food secure
# 6      Not in core housing need                Food secure
# 11     Not in core housing need                Food secure
# 14     Not in core housing need                Food secure
# 16     Not in core housing need                Food secure
# 18                   Valid skip     Severely food insecure
# 24     Not in core housing need                Food secure
# 26     Not in core housing need                Food secure
# 28     Not in core housing need                Food secure
# 32                   Valid skip                Food secure
# 36     Not in core housing need                Food secure
# 38         In core housing need     Severely food insecure
# 40                   Valid skip   Marginally food insecure
# 41                   Valid skip                Food secure
# 44                   Valid skip                Food secure
# 46     Not in core housing need                Food secure
# 48                   Valid skip                Food secure
# 51     Not in core housing need                Food secure
# 52                   Valid skip                Food secure
# 54                   Valid skip                Food secure
# 58         In core housing need     Severely food insecure
# 59     Not in core housing need                Food secure
# 61     Not in core housing need   Moderately food insecure
# 64     Not in core housing need   Marginally food insecure
# 69     Not in core housing need   Marginally food insecure
# 71                   Valid skip   Marginally food insecure
# 77     Not in core housing need                Food secure
# 78                   Valid skip   Marginally food insecure
# 79                   Valid skip                Food secure
# 80                   Valid skip   Marginally food insecure
# 82     Not in core housing need   Moderately food insecure
# 84         In core housing need   Moderately food insecure
# 86     Not in core housing need                Food secure
# 87                   Valid skip                Food secure
# 89                   Valid skip                Food secure
# 91     Not in core housing need                Food secure
# 96                   Valid skip                Food secure
# 102    Not in core housing need                Food secure
# 105    Not in core housing need                Food secure
# 106    Not in core housing need                Food secure
# 108    Not in core housing need                Food secure
# 110                  Valid skip                Food secure
# 113                  Valid skip   Moderately food insecure
# 115    Not in core housing need                Food secure
# 118                  Valid skip   Moderately food insecure
# 120        In core housing need   Moderately food insecure
# 121    Not in core housing need                Food secure
# 124    Not in core housing need   Marginally food insecure
#
#      child_food_security_status  household_food_security_status     atinc35  \
# 0                    Valid skip                     Food secure  1291.21005
# 2                    Valid skip                     Food secure  2402.73290
# 5                    Valid skip                     Food secure  3272.72815
# 6                   Food secure                     Food secure  2063.04825
# 11                  Food secure                     Food secure   938.10720
# 14                  Food secure                     Food secure   972.09025
# 16                   Valid skip                     Food secure  1723.80115
# 18     Moderately food insecure          Severely food insecure  1883.21520
# 24                   Valid skip                     Food secure  1900.57135
# 26                  Food secure                     Food secure  2029.94030
# 28                  Food secure                     Food secure  1941.84690
# 32                  Food secure                     Food secure  1605.07925
# 36                   Valid skip                     Food secure  1054.34965
# 38                   Valid skip          Severely food insecure   395.98275
# 40                   Valid skip        Marginally food insecure   825.07345
# 41                  Food secure                     Food secure   202.00225
# 44                   Valid skip                     Food secure  1906.55120
# 46                  Food secure                     Food secure  1706.29915
# 48                   Valid skip                     Food secure  1178.75970
# 51                   Valid skip                     Food secure  1282.02150
# 52                   Valid skip                     Food secure   877.28775
# 54                  Food secure                     Food secure  2308.22210
# 58                   Valid skip          Severely food insecure   600.17275
# 59                   Valid skip                     Food secure  2467.19860
# 61                  Food secure        Moderately food insecure  1132.23355
# 64     Moderately food insecure        Moderately food insecure  1678.15010
# 69                  Food secure        Marginally food insecure   648.59495
# 71                  Food secure        Marginally food insecure   991.05075
# 77                   Valid skip                     Food secure   643.78190
# 78                   Valid skip        Marginally food insecure   693.51675
# 79                   Valid skip                     Food secure   600.17275
# 80                   Valid skip        Marginally food insecure  1944.47220
# 82                   Valid skip        Moderately food insecure  1682.52560
# 84                   Valid skip        Moderately food insecure   411.29700
# 86                   Valid skip                     Food secure  2210.50260
# 87                   Valid skip                     Food secure   691.32900
# 89                   Valid skip                     Food secure  1786.37080
# 91                  Food secure                     Food secure  2937.41900
# 96                  Food secure                     Food secure  1244.39220
# 102                  Valid skip                     Food secure  1512.31865
# 105                  Valid skip                     Food secure  1499.33800
# 106                  Valid skip                     Food secure  2992.55030
# 108                  Valid skip                     Food secure  1554.03175
# 110                  Valid skip                     Food secure   636.63525
# 113                  Valid skip        Moderately food insecure  1341.82000
# 115                 Food secure                     Food secure  1522.67400
# 118    Moderately food insecure        Moderately food insecure   970.63175
# 120                  Valid skip        Moderately food insecure   526.66435
# 121                 Food secure                     Food secure  2030.96125
# 124                  Valid skip        Marginally food insecure  2381.29295
#
#     total_household_costs
# 0                  2000.0
# 2                  2900.0
# 5                  1600.0
# 6                  1700.0
# 11                  400.0
# 14                 1100.0
# 16                    0.0
# 18                  500.0
# 24                 2100.0
# 26                 3300.0
# 28                 1100.0
# 32                  800.0
# 36                    0.0
# 38                  500.0
# 40                  600.0
# 41                  900.0
# 44                 1200.0
# 46                    0.0
# 48                 1500.0
# 51                  500.0
# 52                    0.0
# 54                  800.0
# 58                 1000.0
# 59                    0.0
# 61                 1400.0
# 64                  900.0
# 69                 2300.0
# 71                  600.0
# 77                    0.0
# 78                  500.0
# 79                  500.0
# 80                    0.0
# 82                 1500.0
# 84                  900.0
# 86                 1200.0
# 87                    0.0
# 89                  800.0
# 91                 2000.0
# 96                 1100.0
# 102                   0.0
# 105                1800.0
# 106                 900.0
# 108                   0.0
# 110                   0.0
# 113                 700.0
# 115                 500.0
# 118                 600.0
# 120                 200.0
# 121                1100.0
# 124                1800.0
#
# [50 rows x 26 columns]

# %%
# Set affordable_housing_flag
df.loc[(df['total_household_costs'] <= df['atinc35']), 'affordable_housing_flag'] = 'Yes'
# Out:
# C:\Users\tmmcc\AppData\Local\Temp\ipykernel_9908\4331269.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['total_household_costs'] <= df['atinc35']), 'affordable_housing_flag'] = 'Yes'

# %%
# Set non-affordable housing flag
df.loc[(df['total_household_costs'] > df['atinc35']), 'affordable_housing_flag'] = 'No'

# %%
# Check frequency table for affordable_housing_flag
df['affordable_housing_flag'].value_counts()
# Out:
# Yes    33356
# No      7501
# Name: affordable_housing_flag, dtype: int64

# %%
# Apply weight to affordable_housing_costs
df1 = df.groupby('affordable_housing_flag')['sample_weight'].sum()
round(df1.head())
# Out:
# affordable_housing_flag
# No      3705641.0
# Yes    11044703.0
# Name: sample_weight, dtype: float64

# %%
# Group by province
grouped = df.groupby(df.province)

# %%
AB = grouped.get_group("Alberta")

# %%
BC = grouped.get_group("British Columbia")

# %%
SK = grouped.get_group("Saskatchewan")

# %%
MB = grouped.get_group("Manitoba")

# %%
ON = grouped.get_group("Ontario")

# %%
QE = grouped.get_group("Quebec")

# %%
NB = grouped.get_group("New Brunswick")

# %%
NS = grouped.get_group("Nova Scotia")

# %%
PE = grouped.get_group("Prince Edward Island")

# %%
NL = grouped.get_group("Newfoundland and Labrador")

# %%
# Calculate weighted totals of affordable housing flag

# %%
AB_ahf = AB.groupby('affordable_housing_flag')['sample_weight'].sum()
AB_ahf = AB_ahf.rename('Alberta')
round(AB_ahf.head())
# Out:
# affordable_housing_flag
# No      370504.0
# Yes    1242276.0
# Name: Alberta, dtype: float64

# %%
BC_ahf = BC.groupby('affordable_housing_flag')['sample_weight'].sum()
BC_ahf = BC_ahf.rename('British Columbia')
round(BC_ahf.head())
# Out:
# affordable_housing_flag
# No      630707.0
# Yes    1333746.0
# Name: British Columbia, dtype: float64

# %%
MB_ahf = MB.groupby('affordable_housing_flag')['sample_weight'].sum()
MB_ahf = MB_ahf.rename('Manitoba')
round(MB_ahf.head())
# Out:
# affordable_housing_flag
# No     118262.0
# Yes    380639.0
# Name: Manitoba, dtype: float64

# %%
SK_ahf = SK.groupby('affordable_housing_flag')['sample_weight'].sum()
SK_ahf = SK_ahf.rename('Saskatchewan')
round(SK_ahf.head())
# Out:
# affordable_housing_flag
# No      88074.0
# Yes    354245.0
# Name: Saskatchewan, dtype: float64

# %%
ON_ahf = ON.groupby('affordable_housing_flag')['sample_weight'].sum()
ON_ahf = ON_ahf.rename('Ontario')
round(ON_ahf.head())
# Out:
# affordable_housing_flag
# No     1738628.0
# Yes    3813378.0
# Name: Ontario, dtype: float64

# %%
QE_ahf = QE.groupby('affordable_housing_flag')['sample_weight'].sum()
QE_ahf = QE_ahf.rename('Quebec')
round(QE_ahf.head())
# Out:
# affordable_housing_flag
# No      615417.0
# Yes    3049299.0
# Name: Quebec, dtype: float64

# %%
NB_ahf = NB.groupby('affordable_housing_flag')['sample_weight'].sum()
NB_ahf = NB_ahf.rename('New Brunswick')
round(NB_ahf.head())
# Out:
# affordable_housing_flag
# No      33691.0
# Yes    289520.0
# Name: New Brunswick, dtype: float64

# %%
NS_ahf = NS.groupby('affordable_housing_flag')['sample_weight'].sum()
NS_ahf = NS_ahf.rename('Nova Scotia')
round(NS_ahf.head())
# Out:
# affordable_housing_flag
# No      72963.0
# Yes    337878.0
# Name: Nova Scotia, dtype: float64

# %%
PE_ahf = PE.groupby('affordable_housing_flag')['sample_weight'].sum()
PE_ahf = PE_ahf.rename('Prince Edward Island')
round(PE_ahf.head())
# Out:
# affordable_housing_flag
# No      8874.0
# Yes    53418.0
# Name: Prince Edward Island, dtype: float64

# %%
NL_ahf = NL.groupby('affordable_housing_flag')['sample_weight'].sum()
NL_ahf = NL_ahf.rename('Newfoundland and Labrador')
round(NL_ahf.head())
# Out:
# affordable_housing_flag
# No      28520.0
# Yes    190305.0
# Name: Newfoundland and Labrador, dtype: float64

# %%
ahf_pop = pd.concat([AB_ahf, BC_ahf, SK_ahf, MB_ahf, ON_ahf, QE_ahf, NB_ahf, NS_ahf, PE_ahf, NL_ahf], axis=1).reset_index()
round(ahf_pop.head())
# Out:
#   affordable_housing_flag    Alberta  British Columbia  Saskatchewan  \
# 0                      No   370504.0          630707.0       88074.0
# 1                     Yes  1242276.0         1333746.0      354245.0
#
#    Manitoba    Ontario     Quebec  New Brunswick  Nova Scotia  \
# 0  118262.0  1738628.0   615417.0        33691.0      72963.0
# 1  380639.0  3813378.0  3049299.0       289520.0     337878.0
#
#    Prince Edward Island  Newfoundland and Labrador
# 0                8874.0                    28520.0
# 1               53418.0                   190305.0

# %%
# Transpose dataframe
ahf_pop_T = ahf_pop.transpose().reset_index()
ahf_pop_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   11 non-null     object
#  1   0       11 non-null     object
#  2   1       11 non-null     object
# dtypes: object(3)
# memory usage: 392.0+ bytes

# %%
ahf_pop_T = ahf_pop_T.rename(columns={
    'index': 'province',
    0 : 'not affordable',
    1 : 'affordable'
})

ahf_pop_T
# Out:
#                      province not affordable    affordable
# 0     affordable_housing_flag             No           Yes
# 1                     Alberta    370504.4949  1242275.5083
# 2            British Columbia     630707.238   1333745.763
# 3                Saskatchewan     88073.8759   354245.1225
# 4                    Manitoba    118261.8779   380639.1179
# 5                     Ontario   1738627.5505  3813378.4483
# 6                      Quebec    615417.3774  3049298.6221
# 7               New Brunswick     33691.4132   289519.5898
# 8                 Nova Scotia     72963.0334   337877.9689
# 9        Prince Edward Island       8873.825    53418.1746
# 10  Newfoundland and Labrador     28520.0973    190304.903

# %%
# Drop first row
ahf_pop_T = ahf_pop_T.iloc[1: , :]
ahf_pop_T
# Out:
#                      province not affordable    affordable
# 1                     Alberta    370504.4949  1242275.5083
# 2            British Columbia     630707.238   1333745.763
# 3                Saskatchewan     88073.8759   354245.1225
# 4                    Manitoba    118261.8779   380639.1179
# 5                     Ontario   1738627.5505  3813378.4483
# 6                      Quebec    615417.3774  3049298.6221
# 7               New Brunswick     33691.4132   289519.5898
# 8                 Nova Scotia     72963.0334   337877.9689
# 9        Prince Edward Island       8873.825    53418.1746
# 10  Newfoundland and Labrador     28520.0973    190304.903

# %%
# Export dataframe to Excel
ahf_pop_T.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'canada_affordable_housing.csv'), index=False)

# %% [markdown]
# # 05 After-tax income brackets

# %%
# Set income brackets
NS.loc[(NS['after_tax_income'] < 40000), 'income_bracket'] = '< 40k'
# Out:
# C:\Users\tmmcc\AppData\Local\Temp\ipykernel_9908\704777341.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NS.loc[(NS['after_tax_income'] < 40000), 'income_bracket'] = '< 40k'

# %%
NS.loc[((NS['after_tax_income'] >= 40000) & (NS['after_tax_income'] < 60000)), 'income_bracket'] = '40k - 60k'

# %%
NS.loc[((NS['after_tax_income'] >= 60000) & (NS['after_tax_income'] < 80000)), 'income_bracket'] = '60k - 80k'

# %%
NS.loc[((NS['after_tax_income'] >= 80000) & (NS['after_tax_income'] < 100000)), 'income_bracket'] = '80k - 100k'

# %%
NS.loc[((NS['after_tax_income'] >= 100000) & (NS['after_tax_income'] < 200000)), 'income_bracket'] = '100k - 200k'

# %%
NS.loc[(NS['after_tax_income'] > 200000), 'income_bracket'] = '> 200k'

# %%
# View frequency table of income_flag
NS['income_bracket'].value_counts()
# Out:
# < 40k          1134
# 40k - 60k       655
# 60k - 80k       335
# 80k - 100k      144
# 100k - 200k      89
# > 200k            9
# Name: income_bracket, dtype: int64

# %%
# Calculate weighted totals of income_bracket
NS_wt_income = NS.groupby('income_bracket')['sample_weight'].sum()
round(NS_wt_income.head())
# Out:
# income_bracket
# 100k - 200k     15320.0
# 40k - 60k      114366.0
# 60k - 80k       57288.0
# 80k - 100k      25808.0
# < 40k          196041.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_wt_income = pd.concat([NS_wt_income], axis=1).reset_index()
NS_wt_income = NS_wt_income.rename(columns={'sample_weight':'count'})
round(NS_wt_income.head())
# Out:
#   income_bracket     count
# 0    100k - 200k   15320.0
# 1      40k - 60k  114366.0
# 2      60k - 80k   57288.0
# 3     80k - 100k   25808.0
# 4          < 40k  196041.0

# %%
# Export series
NS_wt_income.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_income_bracket.csv'), index=False)

# %% [markdown]
# # 06 Age Group

# %%
# Calculate weighted totals of age_group
NS_wt_age = NS.groupby('age_group')['sample_weight'].sum()
round(NS_wt_age.head())
# Out:
# age_group
# 18 to 24 years    15299.0
# 25 to 29 years    27645.0
# 30 to 34 years    36957.0
# 35 to 39 years    30407.0
# 40 to 44 years    27864.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_wt_age = pd.concat([NS_wt_age], axis=1).reset_index()
NS_wt_age = NS_wt_age.rename(columns={'sample_weight':'count'})
round(NS_wt_age.head())
# Out:
#         age_group    count
# 0  18 to 24 years  15299.0
# 1  25 to 29 years  27645.0
# 2  30 to 34 years  36957.0
# 3  35 to 39 years  30407.0
# 4  40 to 44 years  27864.0

# %%
# Export series to dataframe
NS_wt_age.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_age_groups.csv'), index=False)

# %% [markdown]
# # 07 Household Size

# %%
# Calculate weighted totals of household size
NS_wt_hh_size = NS.groupby('household_size')['sample_weight'].sum()
round(NS_wt_hh_size.head())
# Out:
# household_size
# 1    121870.0
# 2    162789.0
# 3     50493.0
# 4     50871.0
# 5     17921.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_wt_hh_size = pd.concat([NS_wt_hh_size], axis=1).reset_index()
NS_wt_hh_size = NS_wt_hh_size.rename(columns={'sample_weight':'count'})
round(NS_wt_hh_size.head())
# Out:
#    household_size     count
# 0               1  121870.0
# 1               2  162789.0
# 2               3   50493.0
# 3               4   50871.0
# 4               5   17921.0

# %%
# Export series to dataframe
NS_wt_hh_size.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_household_size.csv'), index=False)

# %% [markdown]
# # 08 Before- and After-tax low-income flags

# %%
# Calculate weighted totals of low-income flag
NS_wt_atli_flag = NS.groupby('after_tax_low_income_flag')['sample_weight'].sum()
round(NS_wt_atli_flag.head())
# Out:
# after_tax_low_income_flag
# No     377539.0
# Yes     33302.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_wt_atli_flag = pd.concat([NS_wt_atli_flag], axis=1).reset_index()
NS_wt_atli_flag = NS_wt_atli_flag.rename(columns={'sample_weight':'count'})
round(NS_wt_atli_flag.head())
# Out:
#   after_tax_low_income_flag     count
# 0                        No  377539.0
# 1                       Yes   33302.0

# %%
# Export series to dataframe
NS_wt_atli_flag.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_atinc_low.csv'), index=False)

# %%
# Calculate weighted totals of low-income flag
NS_wt_btli_flag = NS.groupby('before_tax_low_income_flag')['sample_weight'].sum()
round(NS_wt_btli_flag.head())
# Out:
# before_tax_low_income_flag
# No     360769.0
# Yes     50072.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_wt_btli_flag = pd.concat([NS_wt_btli_flag], axis=1).reset_index()
NS_wt_btli_flag = NS_wt_btli_flag.rename(columns={'sample_weight':'count'})
round(NS_wt_btli_flag.head())
# Out:
#   before_tax_low_income_flag     count
# 0                         No  360769.0
# 1                        Yes   50072.0

# %%
# Export series to dataframe
NS_wt_btli_flag.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_btinc_low.csv'), index=False)

# %% [markdown]
# # 09 Disposable income... flag

# %%
# Calculate weighted totals of disposable_income... flag
NS_wt_disposable_flag = NS.groupby('disposable_income_below_mbm_flag')['sample_weight'].sum()
round(NS_wt_disposable_flag.head())
# Out:
# disposable_income_below_mbm_flag
# No     347846.0
# Yes     62995.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_wt_disposable_flag = pd.concat([NS_wt_disposable_flag], axis=1).reset_index()
NS_wt_disposable_flag = NS_wt_disposable_flag.rename(columns={'sample_weight':'count'})
round(NS_wt_disposable_flag.head())
# Out:
#   disposable_income_below_mbm_flag     count
# 0                               No  347846.0
# 1                              Yes   62995.0

# %%
# Export series to dataframe
NS_wt_disposable_flag.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_mbm.csv'), index=False)

# %% [markdown]
# # 10 Ownership of dwelling

# %%
# Calculate weighted totals of ownership of dwelling
NS_wt_ownership = NS.groupby('ownership_of_dwelling')['sample_weight'].sum()
round(NS_wt_ownership.head())
# Out:
# ownership_of_dwelling
# Not owned by a member of the household    126539.0
# Owned by a member of the household        284302.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_wt_ownership = pd.concat([NS_wt_ownership], axis=1).reset_index()
NS_wt_ownership = NS_wt_ownership.rename(columns={'sample_weight':'count'})
round(NS_wt_ownership.head())
# Out:
#                     ownership_of_dwelling     count
# 0  Not owned by a member of the household  126539.0
# 1      Owned by a member of the household  284302.0

# %%
# Export series to dataframe
NS_wt_ownership.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_ownership.csv'), index=False)

# %% [markdown]
# # 11 Affordable Housing

# %%
# Calculate weighted totals of affordable housing flag
NS_ahf2 = NS.groupby('affordable_housing_flag')['sample_weight'].sum()
round(NS_ahf2.head())
# Out:
# affordable_housing_flag
# No      72963.0
# Yes    337878.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_ahf2 = pd.concat([NS_ahf2], axis=1).reset_index()
NS_ahf2 = NS_ahf2.rename(columns={'sample_weight':'count'})
round(NS_ahf2.head())
# Out:
#   affordable_housing_flag     count
# 0                      No   72963.0
# 1                     Yes  337878.0

# %%
# Export series to dataframe
NS_ahf2.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_affordable.csv'), index=False)

# %% [markdown]
# # 12 Total household costs flag

# %%
# Look at total household costs
NS['total_household_costs'].min()
# Out:
# 0.0

# %%
# Look at total household costs
NS['total_household_costs'].max()
# Out:
# 2900.0

# %%
# Set household costs flag brackets
NS.loc[(NS['total_household_costs'] == 0), 'housing_costs_flag'] = 'House paid in full'
# Out:
# C:\Users\tmmcc\AppData\Local\Temp\ipykernel_9908\3397228061.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NS.loc[(NS['total_household_costs'] == 0), 'housing_costs_flag'] = 'House paid in full'

# %%
NS.loc[((NS['total_household_costs'] > 0) & (NS['total_household_costs'] < 800)), 'housing_costs_flag'] = '< $800/month'

# %%
NS.loc[((NS['total_household_costs'] >= 800) & (NS['total_household_costs'] < 1600)), 'housing_costs_flag'] = '$800 - $1600 /month'

# %%
NS.loc[((NS['total_household_costs'] >= 1600) & (NS['total_household_costs'] < 2400)), 'housing_costs_flag'] = '$1600 - $2400 /month'

# %%
NS.loc[(NS['total_household_costs'] > 2400), 'housing_costs_flag'] = '> $2400 /month'

# %%
# View frequency table of income_flag
NS['housing_costs_flag'].value_counts()
# Out:
# House paid in full      864
# $800 - $1600 /month     712
# < $800/month            648
# $1600 - $2400 /month    118
# > $2400 /month           19
# Name: housing_costs_flag, dtype: int64

# %%
# Calculate weighted totals of housing_costs_flag
NS_housing_flag = NS.groupby('housing_costs_flag')['sample_weight'].sum()
round(NS_housing_flag.head())
# Out:
# housing_costs_flag
# $1600 - $2400 /month     25721.0
# $800 - $1600 /month     137426.0
# < $800/month            106793.0
# > $2400 /month            3920.0
# House paid in full      136134.0
# Name: sample_weight, dtype: float64

# %%
# Convert series to dataframe
NS_housing_flag = pd.concat([NS_housing_flag], axis=1).reset_index()
NS_housing_flag = NS_housing_flag.rename(columns={'sample_weight':'count'})
round(NS_housing_flag.head())
# Out:
#      housing_costs_flag     count
# 0  $1600 - $2400 /month   25721.0
# 1   $800 - $1600 /month  137426.0
# 2          < $800/month  106793.0
# 3        > $2400 /month    3920.0
# 4    House paid in full  136134.0

# %%
# Export series to dataframe
NS_housing_flag.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS_housing.csv'), index=False)

# %%
# Export NS dataframe
NS.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'NS.csv'), index=False)
